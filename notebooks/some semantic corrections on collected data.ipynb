# %%
import pandas as pd
from tqdm import trange

df = pd.read_csv("phonesdata.csv")

# %%
df
# Out:
#                        Phone Title  \
# 0                  Gionee M7 Power
# 1                        Gionee M7
# 2     Samsung Galaxy M21 6GB/128GB
# 3      Samsung Galaxy M21 4GB/64GB
# 4     Samsung Galaxy A31 6GB/128GB
# ...                            ...
# 1143              Nokia 105 (2019)
# 1144                  Nokia 220 4G
# 1145                     Nokia X71
# 1146            Nokia 2.2 3GB/32GB
# 1147            Nokia 2.2 2GB/16GB
#
#                                                   Specs Price(Kshs)  Rating  \
# 0     Screen::6.0 inches, 720 x 1440 pixels,,Front C...         NaN     4.0
# 1     Screen::6.01 inches, 1080 x 2160 pixels,,Front...         NaN     4.5
# 2     Screen::6.4 inches, 1080 x 2340 pixels,,Front ...         NaN     4.3
# 3     Screen::6.4 inches, 1080 x 2340 pixels,,Front ...      22,499     3.8
# 4     Screen::6.4 inches, 1080 x 2400 pixels,,Front ...      24,999     3.8
# ...                                                 ...         ...     ...
# 1143  Screen::1.77 inches, 120 x 160 pixels,,Front C...       1,900     3.0
# 1144  Screen::2.4 inches, 240 x 320 pixels,,Front Ca...         NaN     4.0
# 1145  Screen::6.39 inches, 1080 x 2316 pixels,,Front...         NaN     3.0
# 1146  Screen::5.71 inches, 720 x 1520 pixels,,Front ...         NaN     3.4
# 1147  Screen::5.71 inches, 720 x 1520 pixels,,Front ...       9,500     3.9
#
#      Specs Score  Likes
# 0            56%     13
# 1            69%      8
# 2           100%     30
# 3            94%     31
# 4            98%     31
# ...          ...    ...
# 1143          8%     11
# 1144         11%      8
# 1145         93%     53
# 1146         47%     50
# 1147         45%     39
#
# [1148 rows x 6 columns]

# %%
for i in trange(len(df)):
    df.loc[i, 'Specs'] = df.loc[i, 'Specs'].replace("Screen::", "Screen:")
    df.loc[i, 'Specs'] = df.loc[i, 'Specs'].replace("pixels,,", "pixels,")
    df.loc[i, 'Specs'] = df.loc[i, 'Specs'].replace("Front Camera::", "Front Camera:")
    df.loc[i, 'Specs'] = df.loc[i, 'Specs'].replace("MP,,", "MP,")
    df.loc[i, 'Specs'] = df.loc[i, 'Specs'].replace("OS::", "OS:")
    df.loc[i, 'Specs'] = df.loc[i, 'Specs'].replace(",,Storage::", ",Storage:")
    df.loc[i, 'Specs'] = df.loc[i, 'Specs'].replace(",,RAM::", ",RAM:")
    df.loc[i, 'Specs'] = df.loc[i, 'Specs'].replace(",,Battery::", ",Battery:")
# Out:
# 100%|██████████| 1148/1148 [00:03<00:00, 328.13it/s]

# %%
df
# Out:
#                        Phone Title  \
# 0                  Gionee M7 Power
# 1                        Gionee M7
# 2     Samsung Galaxy M21 6GB/128GB
# 3      Samsung Galaxy M21 4GB/64GB
# 4     Samsung Galaxy A31 6GB/128GB
# ...                            ...
# 1143              Nokia 105 (2019)
# 1144                  Nokia 220 4G
# 1145                     Nokia X71
# 1146            Nokia 2.2 3GB/32GB
# 1147            Nokia 2.2 2GB/16GB
#
#                                                   Specs Price(Kshs)  Rating  \
# 0     Screen:6.0 inches, 720 x 1440 pixels,Front Cam...         NaN     4.0
# 1     Screen:6.01 inches, 1080 x 2160 pixels,Front C...         NaN     4.5
# 2     Screen:6.4 inches, 1080 x 2340 pixels,Front Ca...         NaN     4.3
# 3     Screen:6.4 inches, 1080 x 2340 pixels,Front Ca...      22,499     3.8
# 4     Screen:6.4 inches, 1080 x 2400 pixels,Front Ca...      24,999     3.8
# ...                                                 ...         ...     ...
# 1143  Screen:1.77 inches, 120 x 160 pixels,Front Cam...       1,900     3.0
# 1144  Screen:2.4 inches, 240 x 320 pixels,Front Came...         NaN     4.0
# 1145  Screen:6.39 inches, 1080 x 2316 pixels,Front C...         NaN     3.0
# 1146  Screen:5.71 inches, 720 x 1520 pixels,Front Ca...         NaN     3.4
# 1147  Screen:5.71 inches, 720 x 1520 pixels,Front Ca...       9,500     3.9
#
#      Specs Score  Likes
# 0            56%     13
# 1            69%      8
# 2           100%     30
# 3            94%     31
# 4            98%     31
# ...          ...    ...
# 1143          8%     11
# 1144         11%      8
# 1145         93%     53
# 1146         47%     50
# 1147         45%     39
#
# [1148 rows x 6 columns]

# %%
df.columns = ['Phone Title', 'Specs', 'Price(Kshs)', 'Rating', 'Specs Score', 'Likes']

# %%
df.head(1)
# Out:
#        Phone Title                                              Specs  \
# 0  Gionee M7 Power  Screen:6.0 inches, 720 x 1440 pixels,Front Cam...
#
#   Price(Kshs)  Rating Specs Score  Likes
# 0         NaN     4.0         56%     13

# %%
# stripping
df['Phone Title'] = df['Phone Title'].apply(lambda s: str(s).strip())
df.Specs = df.Specs.apply(lambda s: s.strip())
df['Price(Kshs)'] = df['Price(Kshs)'].apply(lambda s: str(s).strip())
df['Rating'] = df['Rating'].apply(lambda s: str(s).strip())
df['Specs Score'] = df['Specs Score'].apply(lambda s: str(s).strip())
df.Likes = df.Likes.apply(lambda s: str(s).strip())

# %%
df.head()
# Out:
#                     Phone Title  \
# 0               Gionee M7 Power
# 1                     Gionee M7
# 2  Samsung Galaxy M21 6GB/128GB
# 3   Samsung Galaxy M21 4GB/64GB
# 4  Samsung Galaxy A31 6GB/128GB
#
#                                                Specs Price(Kshs) Rating  \
# 0  Screen::6.0 inches, 720 x 1440 pixels,,Front C...         nan    4.0
# 1  Screen::6.01 inches, 1080 x 2160 pixels,,Front...         nan    4.5
# 2  Screen::6.4 inches, 1080 x 2340 pixels,,Front ...         nan    4.3
# 3  Screen::6.4 inches, 1080 x 2340 pixels,,Front ...      22,499    3.8
# 4  Screen::6.4 inches, 1080 x 2400 pixels,,Front ...      24,999    3.8
#
#   Specs Score Likes
# 0         56%    13
# 1         69%     8
# 2        100%    30
# 3         94%    31
# 4         98%    31

# %%
#df.to_csv("phonesdata.csv", index=False)

# %% [markdown]
# ### Phonesdata with added prices from jumia.co.ke

# %%
df2 = pd.read_csv("phonesdata2.csv")

# %%
df2
# Out:
#              Phone Title                                              Specs  \
# 0              Gionee+M7  Screen::6.0 inches, 720 x 1440 pixels,,Front C...
# 1                 Gionee  Screen::6.01 inches, 1080 x 2160 pixels,,Front...
# 2     Samsung+Galaxy+M21  Screen::6.4 inches, 1080 x 2340 pixels,,Front ...
# 3     Samsung+Galaxy+M21  Screen::6.4 inches, 1080 x 2340 pixels,,Front ...
# 4     Samsung+Galaxy+A31  Screen::6.4 inches, 1080 x 2400 pixels,,Front ...
# ...                  ...                                                ...
# 1143           Nokia+105  Screen::1.77 inches, 120 x 160 pixels,,Front C...
# 1144           Nokia+220  Screen::2.4 inches, 240 x 320 pixels,,Front Ca...
# 1145               Nokia  Screen::6.39 inches, 1080 x 2316 pixels,,Front...
# 1146            Nokia+22  Screen::5.71 inches, 720 x 1520 pixels,,Front ...
# 1147            Nokia+22  Screen::5.71 inches, 720 x 1520 pixels,,Front ...
#
#      Price(Kshs)  Rating Specs Score  Likes PriceJumia(Kshs)
# 0            NaN     4.0         56%     13       KSh 11,800
# 1            NaN     4.5         69%      8        KSh 7,999
# 2            NaN     4.3        100%     30       KSh 22,590
# 3         22,499     3.8         94%     31       KSh 22,590
# 4         24,999     3.8         98%     31       KSh 24,399
# ...          ...     ...         ...    ...              ...
# 1143       1,900     3.0          8%     11              NaN
# 1144         NaN     4.0         11%      8              NaN
# 1145         NaN     3.0         93%     53              NaN
# 1146         NaN     3.4         47%     50              NaN
# 1147       9,500     3.9         45%     39              NaN
#
# [1148 rows x 7 columns]

# %%
df2['Phone Title'] = df['Phone Title']

display(df2)
# Out:
#                       Phone Title  \
# 0                 Gionee M7 Power
# 1                       Gionee M7
# 2     Samsung Galaxy M21 6GB128GB
# 3      Samsung Galaxy M21 4GB64GB
# 4     Samsung Galaxy A31 6GB128GB
# ...                           ...
# 1143               Nokia 105 2019
# 1144                 Nokia 220 4G
# 1145                    Nokia X71
# 1146             Nokia 22 3GB32GB
# 1147             Nokia 22 2GB16GB
#
#                                                   Specs Price(Kshs)  Rating  \
# 0     Screen::6.0 inches, 720 x 1440 pixels,,Front C...         NaN     4.0
# 1     Screen::6.01 inches, 1080 x 2160 pixels,,Front...         NaN     4.5
# 2     Screen::6.4 inches, 1080 x 2340 pixels,,Front ...         NaN     4.3
# 3     Screen::6.4 inches, 1080 x 2340 pixels,,Front ...      22,499     3.8
# 4     Screen::6.4 inches, 1080 x 2400 pixels,,Front ...      24,999     3.8
# ...                                                 ...         ...     ...
# 1143  Screen::1.77 inches, 120 x 160 pixels,,Front C...       1,900     3.0
# 1144  Screen::2.4 inches, 240 x 320 pixels,,Front Ca...         NaN     4.0
# 1145  Screen::6.39 inches, 1080 x 2316 pixels,,Front...         NaN     3.0
# 1146  Screen::5.71 inches, 720 x 1520 pixels,,Front ...         NaN     3.4
# 1147  Screen::5.71 inches, 720 x 1520 pixels,,Front ...       9,500     3.9
#
#      Specs Score  Likes PriceJumia(Kshs)
# 0            56%     13       KSh 11,800
# 1            69%      8        KSh 7,999
# 2           100%     30       KSh 22,590
# 3            94%     31       KSh 22,590
# 4            98%     31       KSh 24,399
# ...          ...    ...              ...
# 1143          8%     11              NaN
# 1144         11%      8              NaN
# 1145         93%     53              NaN
# 1146         47%     50              NaN
# 1147         45%     39              NaN
#
# [1148 rows x 7 columns]

# %%
df2['Specs'] = df['Specs']
display(df2)
# Out:
#                       Phone Title  \
# 0                 Gionee M7 Power
# 1                       Gionee M7
# 2     Samsung Galaxy M21 6GB128GB
# 3      Samsung Galaxy M21 4GB64GB
# 4     Samsung Galaxy A31 6GB128GB
# ...                           ...
# 1143               Nokia 105 2019
# 1144                 Nokia 220 4G
# 1145                    Nokia X71
# 1146             Nokia 22 3GB32GB
# 1147             Nokia 22 2GB16GB
#
#                                                   Specs Price(Kshs)  Rating  \
# 0     Screen:6.0 inches, 720 x 1440 pixels,Front Cam...         NaN     4.0
# 1     Screen:6.01 inches, 1080 x 2160 pixels,Front C...         NaN     4.5
# 2     Screen:6.4 inches, 1080 x 2340 pixels,Front Ca...         NaN     4.3
# 3     Screen:6.4 inches, 1080 x 2340 pixels,Front Ca...      22,499     3.8
# 4     Screen:6.4 inches, 1080 x 2400 pixels,Front Ca...      24,999     3.8
# ...                                                 ...         ...     ...
# 1143  Screen:1.77 inches, 120 x 160 pixels,Front Cam...       1,900     3.0
# 1144  Screen:2.4 inches, 240 x 320 pixels,Front Came...         NaN     4.0
# 1145  Screen:6.39 inches, 1080 x 2316 pixels,Front C...         NaN     3.0
# 1146  Screen:5.71 inches, 720 x 1520 pixels,Front Ca...         NaN     3.4
# 1147  Screen:5.71 inches, 720 x 1520 pixels,Front Ca...       9,500     3.9
#
#      Specs Score  Likes PriceJumia(Kshs)
# 0            56%     13       KSh 11,800
# 1            69%      8        KSh 7,999
# 2           100%     30       KSh 22,590
# 3            94%     31       KSh 22,590
# 4            98%     31       KSh 24,399
# ...          ...    ...              ...
# 1143          8%     11              NaN
# 1144         11%      8              NaN
# 1145         93%     53              NaN
# 1146         47%     50              NaN
# 1147         45%     39              NaN
#
# [1148 rows x 7 columns]

# %%
df2['PriceJumia(Kshs)'] = df2['PriceJumia(Kshs)'].apply(lambda s: str(s).strip())
df2['PriceJumia(Kshs)'] = df2['PriceJumia(Kshs)'].apply(lambda s: str(s).split("Ksh ")[-1])
display(df2.head(2))
# Out:
#        Phone Title                                              Specs  \
# 0  Gionee M7 Power  Screen:6.0 inches, 720 x 1440 pixels,Front Cam...
# 1        Gionee M7  Screen:6.01 inches, 1080 x 2160 pixels,Front C...
#
#   Price(Kshs)  Rating Specs Score  Likes PriceJumia(Kshs)
# 0         NaN     4.0         56%     13           11,800
# 1         NaN     4.5         69%      8            7,999

# %%
df2.to_csv("phonesdata2.csv", index=False)

# %% [markdown]
# ### Making one price column

# %%
# We saved df2 first to take care of type nans
df2 = pd.read_csv("phonesdata2.csv")
display(df2)
# Out:
#                       Phone Title  \
# 0                 Gionee M7 Power
# 1                       Gionee M7
# 2     Samsung Galaxy M21 6GB128GB
# 3      Samsung Galaxy M21 4GB64GB
# 4     Samsung Galaxy A31 6GB128GB
# ...                           ...
# 1143               Nokia 105 2019
# 1144                 Nokia 220 4G
# 1145                    Nokia X71
# 1146             Nokia 22 3GB32GB
# 1147             Nokia 22 2GB16GB
#
#                                                   Specs Price(Kshs)  Rating  \
# 0     Screen:6.0 inches, 720 x 1440 pixels,Front Cam...         NaN     4.0
# 1     Screen:6.01 inches, 1080 x 2160 pixels,Front C...         NaN     4.5
# 2     Screen:6.4 inches, 1080 x 2340 pixels,Front Ca...         NaN     4.3
# 3     Screen:6.4 inches, 1080 x 2340 pixels,Front Ca...      22,499     3.8
# 4     Screen:6.4 inches, 1080 x 2400 pixels,Front Ca...      24,999     3.8
# ...                                                 ...         ...     ...
# 1143  Screen:1.77 inches, 120 x 160 pixels,Front Cam...       1,900     3.0
# 1144  Screen:2.4 inches, 240 x 320 pixels,Front Came...         NaN     4.0
# 1145  Screen:6.39 inches, 1080 x 2316 pixels,Front C...         NaN     3.0
# 1146  Screen:5.71 inches, 720 x 1520 pixels,Front Ca...         NaN     3.4
# 1147  Screen:5.71 inches, 720 x 1520 pixels,Front Ca...       9,500     3.9
#
#      Specs Score  Likes PriceJumia(Kshs)
# 0            56%     13           11,800
# 1            69%      8            7,999
# 2           100%     30           22,590
# 3            94%     31           22,590
# 4            98%     31           24,399
# ...          ...    ...              ...
# 1143          8%     11              NaN
# 1144         11%      8              NaN
# 1145         93%     53              NaN
# 1146         47%     50              NaN
# 1147         45%     39              NaN
#
# [1148 rows x 7 columns]

# %%
for i in trange(len(df2)):
    if type(df2.loc[i, 'Price(Kshs)']) == float:
        df2.loc[i, 'Price(Kshs)'] = df2.loc[i, 'PriceJumia(Kshs)']
    else:
        pass
# Out:
# 100%|██████████| 1148/1148 [00:00<00:00, 3023.96it/s]

# %%
df2
# Out:
#                       Phone Title  \
# 0                 Gionee M7 Power
# 1                       Gionee M7
# 2     Samsung Galaxy M21 6GB128GB
# 3      Samsung Galaxy M21 4GB64GB
# 4     Samsung Galaxy A31 6GB128GB
# ...                           ...
# 1143               Nokia 105 2019
# 1144                 Nokia 220 4G
# 1145                    Nokia X71
# 1146             Nokia 22 3GB32GB
# 1147             Nokia 22 2GB16GB
#
#                                                   Specs Price(Kshs)  Rating  \
# 0     Screen:6.0 inches, 720 x 1440 pixels,Front Cam...      11,800     4.0
# 1     Screen:6.01 inches, 1080 x 2160 pixels,Front C...       7,999     4.5
# 2     Screen:6.4 inches, 1080 x 2340 pixels,Front Ca...      22,590     4.3
# 3     Screen:6.4 inches, 1080 x 2340 pixels,Front Ca...      22,499     3.8
# 4     Screen:6.4 inches, 1080 x 2400 pixels,Front Ca...      24,999     3.8
# ...                                                 ...         ...     ...
# 1143  Screen:1.77 inches, 120 x 160 pixels,Front Cam...       1,900     3.0
# 1144  Screen:2.4 inches, 240 x 320 pixels,Front Came...         NaN     4.0
# 1145  Screen:6.39 inches, 1080 x 2316 pixels,Front C...         NaN     3.0
# 1146  Screen:5.71 inches, 720 x 1520 pixels,Front Ca...         NaN     3.4
# 1147  Screen:5.71 inches, 720 x 1520 pixels,Front Ca...       9,500     3.9
#
#      Specs Score  Likes PriceJumia(Kshs)
# 0            56%     13           11,800
# 1            69%      8            7,999
# 2           100%     30           22,590
# 3            94%     31           22,590
# 4            98%     31           24,399
# ...          ...    ...              ...
# 1143          8%     11              NaN
# 1144         11%      8              NaN
# 1145         93%     53              NaN
# 1146         47%     50              NaN
# 1147         45%     39              NaN
#
# [1148 rows x 7 columns]

# %%
df2.drop('PriceJumia(Kshs)', axis=1, inplace=True)

# %%
df2.to_csv("phonesdata_final.csv", index=False)
